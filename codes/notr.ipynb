# %%
train_d_path = '/home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/grammer/train_grammer.conll'
dev_d_path = '/home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/grammer/dev_grammer.conll'

# %%
# train_d_path = '/home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/caseMorph_data/dev_caseMorph.conll'
# dev_d_path = '/home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/caseMorph_data/dev_caseMorph.conll'
from tpipeline import TPipeline
trainer = TPipeline(
        training_config={
        'category': 'customized-mwt-ner', # pipeline category
        'task': 'posdep', # task name
        'save_dir': '/home/kabira/Documents/githubs/save_dir_trankit/'+'grammer', # directory for saving trained model
        'train_conllu_fpath': train_d_path, # annotations file in CONLLU format  for training
        'dev_conllu_fpath': dev_d_path, # annotations file in CONLLU format for development
        'max_epoch': 1,
        "batch_size":50
    })

trainer.train()
# Out:
# Setting up training config...
# Loaded 3 entries from /home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/grammer/train_grammer.conll
# Loaded 2 entries from /home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/grammer/dev_grammer.conll
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_77241/3180357836.py in <module>
#       2 # dev_d_path = '/home/kabira/Documents/ai-Compound-Classification/postdep/task2 data with complete info/caseMorph_data/dev_caseMorph.conll'
#       3 from tpipeline import TPipeline
# ----> 4 trainer = TPipeline(
#       5         training_config={
#       6         'category': 'customized-mwt-ner', # pipeline category
#
# ~/Documents/trankit/trankit/tpipeline.py in __init__(self, training_config)
#      41
#      42         elif self._task == 'posdep':
# ...
